# %% [markdown]
# # Ejemplo Series de Tiempo

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.tsa as tsa
import statsmodels as sm
from datetime import datetime
import os
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

#Tensorflow
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential,save_model,load_model
from keras.layers import Dense
from keras.layers import LSTM
from keras.callbacks import EarlyStopping
from keras.metrics import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.optimizers import Adam
from sklearn.metrics import mean_squared_error
import keras

#Pytorch
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

# %% [markdown]
# ## La Serie
#
# Vamos a trabajar con la serie de tiempo AirPassenger. Los datos describen la cantidad total de pasajeros de una aerolínea por mes entre los años 1949 a 1960. Se presentan las primeras 6 filas del conjunto de datos:

# %%
tf.random.set_seed(123)
airPas = pd.read_csv('../data/AirPassengers.csv',parse_dates=['Month'],index_col='Month')
print ('\n Parsed Data:')
print(airPas.head())
# Out:
#  Parsed Data:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %% [markdown]
# A continuación podemos ver el gráfico de la serie.

# %%
plt.plot(airPas)
plt.gca().set(title="Cantidad de pasajeros por mes", xlabel="Año", ylabel="Cantidad de Pasajeros")
plt.show()

# %% [markdown]
# Como se puede ver la serie no es estacionaria en media y la LSTM funciona mejor con series estacionarizadas así que vamos a diferenciarla na vez a ver si es suficiente para estacionarizarla en media

# %%
# Se calcula la media móvil y la desviación estandar móvil de los últimos 12 meses.
mediaMovil = airPas.rolling(window=12).mean()
deMovil = airPas.rolling(window=12).std()
# Se grafican los resultados.
original = plt.plot(airPas, color="blue", label="Original")
media = plt.plot(mediaMovil, color='red', label = 'Media Movil')
ds = plt.plot(deMovil,color='black', label = 'Desviación Estándar Móvil')
plt.legend(loc = 'best')
plt.title('Media y desviación estándar móvil')
plt.show(block=False)

# %%
descomposicion = seasonal_decompose(airPas)
descomposicion.plot();

# %% [markdown]
# En este gráfico se puede observar que hay tendencia por lo que la serie no parece ser estacionaria en media y tampoco en varianza.

# %%
print('Resultados del Test de Dickey Fuller')
dfTest = adfuller(airPas, autolag='AIC')
salidaDf = pd.Series(dfTest[0:4], index=['Estadístico de prueba','p-value','# de retardos usados','# de observaciones usadas'])
for key,value in dfTest[4].items():
        salidaDf['Critical Value (%s)'%key] = value
print(salidaDf)
# Out:
# Resultados del Test de Dickey Fuller
# Estadístico de prueba          0.815369
# p-value                        0.991880
# # de retardos usados          13.000000
# # de observaciones usadas    130.000000
# Critical Value (1%)           -3.481682
# Critical Value (5%)           -2.884042
# Critical Value (10%)          -2.578770
# dtype: float64

# %% [markdown]
# El p-value es mayor a 0.05 por lo que no se puede rechazar la hipótesis nula de que existen raices unitarias. La serie no es estacionaria en media. Vamos a probar con una diferenciación

# %%
print('Resultados del Test de Dickey Fuller para una diferenciación de la serie')
ts_air_pas_diff = airPas.diff()
ts_air_pas_diff.fillna(0,inplace=True)
dfTest = adfuller(ts_air_pas_diff)
salidaDf = pd.Series(dfTest[0:4], index=['Estadístico de prueba','p-value','# de retardos usados','# de observaciones usadas'])
for key,value in dfTest[4].items():
        salidaDf['Critical Value (%s)'%key] = value
print(salidaDf)
# Out:
# Resultados del Test de Dickey Fuller para una diferenciación de la serie
# Estadístico de prueba         -2.889186
# p-value                        0.046620
# # de retardos usados          12.000000
# # de observaciones usadas    131.000000
# Critical Value (1%)           -3.481282
# Critical Value (5%)           -2.883868
# Critical Value (10%)          -2.578677
# dtype: float64

# %%
plt.plot(ts_air_pas_diff)

# %% [markdown]
# Las redes neuronales trabajan mejor con los datos normalizados así que vamos a normalizar la serie:

# %%
scaler = StandardScaler()
ts_air_pas_scaled = scaler.fit_transform(ts_air_pas_diff) 
ts_air_pas_scaled[1:7]
# Out:
# array([[ 0.11270364],
#        [ 0.35137017],
#        [-0.15579621],
#        [-0.30496279],
#        [ 0.35137017],
#        [ 0.32153685]])

# %% [markdown]
# Vamos a separar la serie en entrenamiento, validación y prueba. En este caso, tendremos 60% para entrenamiento y 20% para validación y prueba respectivamente.

# %%
val_prueba = round(0.2*len(ts_air_pas_scaled))
val_prueba
# Out:
# 29

# %%
entrenamiento = round(0.6*len(ts_air_pas_scaled))
val_prueba = round(0.2*len(ts_air_pas_scaled))
test = ts_air_pas_scaled[(entrenamiento+val_prueba)-1:]
validation = ts_air_pas_scaled[(entrenamiento):entrenamiento+val_prueba+1]
train = ts_air_pas_scaled[0:entrenamiento]
train=np.insert(train,0,0)
train=np.reshape(train,(train.shape[0],1))
len(test)
# Out:
# 30

# %% [markdown]
# Para que pueda usarse el argoritmo LSTM es necesario transformar la serie en una supervisada, de manera que las observaciones anteriores sean capaces de estimar la siguiente. En este caso vamos a usar el mes anterior para predecir el siguiente por lo que vamos a transformar el arreglo de numpy en una matriz de dos dimensiones en la que la dimensión 1 sea el instante t-1 y la dimensión 2 sea el instante t

# %%
from operator import concat


def supervisada(serie,retrasos = 1):
    serie_x = []
    serie_y = []
    for i in range(len(serie)-retrasos):
        valor = serie[i:(i+retrasos),0]
        valor_sig = serie[i+retrasos,0]
        serie_x.append(valor)
        serie_y.append(valor_sig)
    return np.array(serie_x), np.array(serie_y)

x_train,y_train = supervisada(train)
x_val,y_val = supervisada(validation)
x_test,y_test = supervisada(test)

# %%
print(train[0:6])
print(x_train[0:6])
print(y_train[0:6])
# Out:
# [[ 0.        ]
#  [-0.06629626]
#  [ 0.11270364]
#  [ 0.35137017]
#  [-0.15579621]
#  [-0.30496279]]
# [[ 0.        ]
#  [-0.06629626]
#  [ 0.11270364]
#  [ 0.35137017]
#  [-0.15579621]
#  [-0.30496279]]
# [-0.06629626  0.11270364  0.35137017 -0.15579621 -0.30496279  0.35137017]

# %% [markdown]
# ## Creando el modelo
# Para que pueda hacerse el modelo se le tiene que suministrar una matriz de 3 dimensiones siendo estas:
# - ***Muestras:*** número de observaciones en cada lote, también conocido como tamaño del lote.
# - ***Pasos de tiempo:*** Pasos de tiempo separados para una observación dada. En este ejemplo los pasos de tiempo = 1
# - ***Características:*** Para un caso univariante, como en este ejemplo, las características = 1
#
# Un modelo LSTM permite ingresar datos a una red y hacer predicciones basados en pasos individuales de datos secuenciales. Como es una serie de tiempo donde queremos predecir el próximo elemento, usaremos un modelo secuencial, para predecir el próximo elemento, por esto es que el paso es 1.
#
# El número de neuronas en la capa de salida (Dense) debe estar en la forma en que necesitamos la salida, en el caso de las series de tiempo necesitamos una neurona porque queremos predecir un valor.
#
# Vamos a convertir los conjuntos en matrices de 3 dimensiones:

# %%
x_train = np.reshape(x_train,(x_train.shape[0],1,1))
x_val = np.reshape(x_val, (x_val.shape[0],1,1))
x_test = np.reshape(x_test, (x_test.shape[0],1,1))
len(x_val)
# Out:
# 29

# %%
x_train
# Out:
# array([[[ 0.        ]],
#
#        [[-0.06629626]],
#
#        [[ 0.11270364]],
#
#        [[ 0.35137017]],
#
#        [[-0.15579621]],
#
#        [[-0.30496279]],
#
#        [[ 0.35137017]],
#
#        [[ 0.32153685]],
#
#        [[-0.06629626]],
#
#        [[-0.42429605]],
#
#        [[-0.57346263]],
#
#        [[-0.513796  ]],
#
#        [[ 0.35137017]],
#
#        [[-0.15579621]],
#
#        [[ 0.26187022]],
#
#        [[ 0.38120348]],
#
#        [[-0.24529616]],
#
#        [[-0.36462942]],
#
#        [[ 0.64970333]],
#
#        [[ 0.56020338]],
#
#        [[-0.06629626]],
#
#        [[-0.42429605]],
#
#        [[-0.81212916]],
#
#        [[-0.63312927]],
#
#        [[ 0.70936996]],
#
#        [[ 0.08287032]],
#
#        [[ 0.08287032]],
#
#        [[ 0.7690366 ]],
#
#        [[-0.513796  ]],
#
#        [[ 0.20220359]],
#
#        [[ 0.11270364]],
#
#        [[ 0.56020338]],
#
#        [[-0.06629626]],
#
#        [[-0.513796  ]],
#
#        [[-0.72262921]],
#
#        [[-0.54362932]],
#
#        [[ 0.53037007]],
#
#        [[ 0.08287032]],
#
#        [[ 0.20220359]],
#
#        [[ 0.32153685]],
#
#        [[-0.42429605]],
#
#        [[-0.00662963]],
#
#        [[ 0.97786981]],
#
#        [[ 0.29170354]],
#
#        [[ 0.29170354]],
#
#        [[-1.05079569]],
#
#        [[-0.60329595]],
#
#        [[-0.63312927]],
#
#        [[ 0.5900367 ]],
#
#        [[-0.00662963]],
#
#        [[-0.06629626]],
#
#        [[ 1.12703639]],
#
#        [[-0.09612957]],
#
#        [[-0.24529616]],
#
#        [[ 0.35137017]],
#
#        [[ 0.56020338]],
#
#        [[ 0.17237027]],
#
#        [[-1.11046233]],
#
#        [[-0.84196248]],
#
#        [[-0.99112906]],
#
#        [[ 0.56020338]],
#
#        [[ 0.02320369]],
#
#        [[-0.54362932]],
#
#        [[ 1.3358696 ]],
#
#        [[-0.30496279]],
#
#        [[ 0.14253696]],
#
#        [[ 0.82870323]],
#
#        [[ 1.06736976]],
#
#        [[-0.3347961 ]],
#
#        [[-1.08062901]],
#
#        [[-0.96129574]],
#
#        [[-0.84196248]],
#
#        [[ 0.70936996]],
#
#        [[ 0.32153685]],
#
#        [[-0.3347961 ]],
#
#        [[ 0.94803649]],
#
#        [[-0.00662963]],
#
#        [[-0.03646294]],
#
#        [[ 1.27620297]],
#
#        [[ 1.39553624]],
#
#        [[-0.57346263]],
#
#        [[-1.11046233]],
#
#        [[-1.19996227]],
#
#        [[-1.17012896]],
#
#        [[ 1.15686971]],
#
#        [[ 0.11270364]]])

# %% [markdown]
# ### Creamos el modelo.
# #### Tensor Flow
# Vamos a utilizar solo una capa LSTM

# %%
lote = 1
unidades =  1
paso = 1
caracteristicas = 1 #es univariada

inputs = keras.layers.Input((paso,caracteristicas))
lstm_out = keras.layers.LSTM(lote)(inputs)
outputs = keras.layers.Dense(1)(lstm_out)

modelo1 = keras.Model(inputs=inputs, outputs=outputs)
modelo1.summary()

#Tensor Flow 2
#modelo1 = Sequential()
#modelo1.add(LSTM(lote,batch_input_shape=(lote,paso,caracteristicas),stateful=True))
#modelo1.add(Dense(1))
#modelo1.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 1, 1)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 1)              │            12 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14 (56.00 B)
#  Trainable params: 14 (56.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Compilamos el modelo. Las métricas que nos van a servir para saber como funciona el modelo en términos de la pérdida es el error medio cuadrado.
# Se le puso una detención temprana para ahorrar tiempo de entrenamiento. Para el entrenamiento del modelo cuando se da cuenta de que no habrá disminución de la pérdida en las siguientes épocas.

# %%
#early_stop = EarlyStopping(monitor='val_loss', patience=1)
modelo1.compile(loss='mean_squared_error',optimizer=Adam(learning_rate=0.1), metrics = [RootMeanSquaredError()])

# %%
modelo1
# Out:
# <Functional name=functional_1, built=True>

# %% [markdown]
# Vamos a entrenar el modelo. Para eso configuramos las épocas que es la cantidad de iteraciones. Lo pondremos en 50.

# %%
epocas = 150
history= modelo1.fit(
    x = x_train,
    y = y_train,
    batch_size = lote,
    epochs = epocas,
    shuffle = False,
    validation_data = (x_val,y_val),
    #callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.4211 - root_mean_squared_error: 0.6489 - val_loss: 1.2929 - val_root_mean_squared_error: 1.1371
# Epoch 2/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4119 - root_mean_squared_error: 0.6418 - val_loss: 1.2119 - val_root_mean_squared_error: 1.1009
# Epoch 3/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3995 - root_mean_squared_error: 0.6321 - val_loss: 1.1770 - val_root_mean_squared_error: 1.0849
# Epoch 4/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3925 - root_mean_squared_error: 0.6265 - val_loss: 1.1652 - val_root_mean_squared_error: 1.0795
# Epoch 5/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3898 - root_mean_squared_error: 0.6243 - val_loss: 1.1585 - val_root_mean_squared_error: 1.0763
# Epoch 6/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3878 - root_mean_squared_error: 0.6228 - val_loss: 1.1536 - val_root_mean_squared_error: 1.0740
# Epoch 7/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3867 - root_mean_squared_error: 0.6219 - val_loss: 1.1495 - val_root_mean_squared_error: 1.0722
# Epoch 8/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3859 - root_mean_squared_error: 0.6212 - val_loss: 1.1464 - val_root_mean_squared_error: 1.0707
# Epoch 9/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3853 - root_mean_squared_error: 0.6207 - val_loss: 1.1438 - val_root_mean_squared_error: 1.0695
# Epoch 10/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3848 - root_mean_squared_error: 0.6203 - val_loss: 1.1417 - val_root_mean_squared_error: 1.0685
# Epoch 11/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3844 - root_mean_squared_error: 0.6200 - val_loss: 1.1399 - val_root_mean_squared_error: 1.0677
# Epoch 12/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3841 - root_mean_squared_error: 0.6198 - val_loss: 1.1385 - val_root_mean_squared_error: 1.0670
# Epoch 13/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3839 - root_mean_squared_error: 0.6196 - val_loss: 1.1373 - val_root_mean_squared_error: 1.0664
# Epoch 14/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3836 - root_mean_squared_error: 0.6194 - val_loss: 1.1363 - val_root_mean_squared_error: 1.0660
# Epoch 15/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3835 - root_mean_squared_error: 0.6192 - val_loss: 1.1355 - val_root_mean_squared_error: 1.0656
# Epoch 16/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3833 - root_mean_squared_error: 0.6191 - val_loss: 1.1348 - val_root_mean_squared_error: 1.0653
# Epoch 17/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3831 - root_mean_squared_error: 0.6190 - val_loss: 1.1343 - val_root_mean_squared_error: 1.0650
# Epoch 18/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3830 - root_mean_squared_error: 0.6189 - val_loss: 1.1338 - val_root_mean_squared_error: 1.0648
# Epoch 19/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3829 - root_mean_squared_error: 0.6188 - val_loss: 1.1335 - val_root_mean_squared_error: 1.0647
# Epoch 20/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3828 - root_mean_squared_error: 0.6187 - val_loss: 1.1332 - val_root_mean_squared_error: 1.0645
# Epoch 21/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3827 - root_mean_squared_error: 0.6186 - val_loss: 1.1331 - val_root_mean_squared_error: 1.0644
# Epoch 22/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3826 - root_mean_squared_error: 0.6186 - val_loss: 1.1329 - val_root_mean_squared_error: 1.0644
# Epoch 23/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3826 - root_mean_squared_error: 0.6185 - val_loss: 1.1328 - val_root_mean_squared_error: 1.0643
# Epoch 24/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3825 - root_mean_squared_error: 0.6185 - val_loss: 1.1328 - val_root_mean_squared_error: 1.0643
# Epoch 25/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3824 - root_mean_squared_error: 0.6184 - val_loss: 1.1328 - val_root_mean_squared_error: 1.0643
# Epoch 26/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3824 - root_mean_squared_error: 0.6184 - val_loss: 1.1328 - val_root_mean_squared_error: 1.0643
# Epoch 27/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3823 - root_mean_squared_error: 0.6183 - val_loss: 1.1328 - val_root_mean_squared_error: 1.0643
# Epoch 28/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3823 - root_mean_squared_error: 0.6183 - val_loss: 1.1329 - val_root_mean_squared_error: 1.0644
# Epoch 29/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3822 - root_mean_squared_error: 0.6182 - val_loss: 1.1330 - val_root_mean_squared_error: 1.0644
# Epoch 30/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3822 - root_mean_squared_error: 0.6182 - val_loss: 1.1331 - val_root_mean_squared_error: 1.0645
# Epoch 31/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3821 - root_mean_squared_error: 0.6182 - val_loss: 1.1332 - val_root_mean_squared_error: 1.0645
# Epoch 32/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3821 - root_mean_squared_error: 0.6181 - val_loss: 1.1333 - val_root_mean_squared_error: 1.0646
# Epoch 33/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3821 - root_mean_squared_error: 0.6181 - val_loss: 1.1335 - val_root_mean_squared_error: 1.0647
# Epoch 34/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3820 - root_mean_squared_error: 0.6181 - val_loss: 1.1337 - val_root_mean_squared_error: 1.0647
# Epoch 35/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3820 - root_mean_squared_error: 0.6180 - val_loss: 1.1338 - val_root_mean_squared_error: 1.0648
# Epoch 36/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3820 - root_mean_squared_error: 0.6180 - val_loss: 1.1340 - val_root_mean_squared_error: 1.0649
# Epoch 37/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3819 - root_mean_squared_error: 0.6180 - val_loss: 1.1342 - val_root_mean_squared_error: 1.0650
# Epoch 38/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3819 - root_mean_squared_error: 0.6180 - val_loss: 1.1343 - val_root_mean_squared_error: 1.0651
# Epoch 39/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3819 - root_mean_squared_error: 0.6180 - val_loss: 1.1345 - val_root_mean_squared_error: 1.0651
# Epoch 40/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3818 - root_mean_squared_error: 0.6179 - val_loss: 1.1347 - val_root_mean_squared_error: 1.0652
# Epoch 41/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3818 - root_mean_squared_error: 0.6179 - val_loss: 1.1349 - val_root_mean_squared_error: 1.0653
# Epoch 42/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3818 - root_mean_squared_error: 0.6179 - val_loss: 1.1351 - val_root_mean_squared_error: 1.0654
# Epoch 43/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3818 - root_mean_squared_error: 0.6179 - val_loss: 1.1353 - val_root_mean_squared_error: 1.0655
# Epoch 44/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3817 - root_mean_squared_error: 0.6179 - val_loss: 1.1355 - val_root_mean_squared_error: 1.0656
# Epoch 45/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3817 - root_mean_squared_error: 0.6178 - val_loss: 1.1357 - val_root_mean_squared_error: 1.0657
# Epoch 46/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3817 - root_mean_squared_error: 0.6178 - val_loss: 1.1359 - val_root_mean_squared_error: 1.0658
# Epoch 47/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3817 - root_mean_squared_error: 0.6178 - val_loss: 1.1361 - val_root_mean_squared_error: 1.0659
# Epoch 48/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3817 - root_mean_squared_error: 0.6178 - val_loss: 1.1363 - val_root_mean_squared_error: 1.0660
# Epoch 49/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3817 - root_mean_squared_error: 0.6178 - val_loss: 1.1365 - val_root_mean_squared_error: 1.0661
# Epoch 50/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3816 - root_mean_squared_error: 0.6178 - val_loss: 1.1367 - val_root_mean_squared_error: 1.0661
# Epoch 51/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3816 - root_mean_squared_error: 0.6178 - val_loss: 1.1369 - val_root_mean_squared_error: 1.0662
# Epoch 52/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3816 - root_mean_squared_error: 0.6177 - val_loss: 1.1371 - val_root_mean_squared_error: 1.0663
# Epoch 53/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3816 - root_mean_squared_error: 0.6177 - val_loss: 1.1373 - val_root_mean_squared_error: 1.0664
# Epoch 54/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3816 - root_mean_squared_error: 0.6177 - val_loss: 1.1374 - val_root_mean_squared_error: 1.0665
# Epoch 55/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3816 - root_mean_squared_error: 0.6177 - val_loss: 1.1376 - val_root_mean_squared_error: 1.0666
# Epoch 56/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3815 - root_mean_squared_error: 0.6177 - val_loss: 1.1378 - val_root_mean_squared_error: 1.0667
# Epoch 57/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3815 - root_mean_squared_error: 0.6177 - val_loss: 1.1380 - val_root_mean_squared_error: 1.0668
# Epoch 58/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3815 - root_mean_squared_error: 0.6177 - val_loss: 1.1382 - val_root_mean_squared_error: 1.0669
# Epoch 59/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3815 - root_mean_squared_error: 0.6177 - val_loss: 1.1384 - val_root_mean_squared_error: 1.0669
# Epoch 60/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3815 - root_mean_squared_error: 0.6176 - val_loss: 1.1385 - val_root_mean_squared_error: 1.0670
# Epoch 61/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3815 - root_mean_squared_error: 0.6176 - val_loss: 1.1387 - val_root_mean_squared_error: 1.0671
# Epoch 62/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3815 - root_mean_squared_error: 0.6176 - val_loss: 1.1389 - val_root_mean_squared_error: 1.0672
# Epoch 63/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3815 - root_mean_squared_error: 0.6176 - val_loss: 1.1391 - val_root_mean_squared_error: 1.0673
# Epoch 64/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3814 - root_mean_squared_error: 0.6176 - val_loss: 1.1392 - val_root_mean_squared_error: 1.0674
# Epoch 65/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3814 - root_mean_squared_error: 0.6176 - val_loss: 1.1394 - val_root_mean_squared_error: 1.0674
# Epoch 66/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3814 - root_mean_squared_error: 0.6176 - val_loss: 1.1396 - val_root_mean_squared_error: 1.0675
# Epoch 67/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3814 - root_mean_squared_error: 0.6176 - val_loss: 1.1397 - val_root_mean_squared_error: 1.0676
# Epoch 68/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3814 - root_mean_squared_error: 0.6176 - val_loss: 1.1399 - val_root_mean_squared_error: 1.0677
# Epoch 69/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3814 - root_mean_squared_error: 0.6176 - val_loss: 1.1401 - val_root_mean_squared_error: 1.0677
# Epoch 70/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3814 - root_mean_squared_error: 0.6176 - val_loss: 1.1402 - val_root_mean_squared_error: 1.0678
# Epoch 71/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3814 - root_mean_squared_error: 0.6176 - val_loss: 1.1404 - val_root_mean_squared_error: 1.0679
# Epoch 72/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3814 - root_mean_squared_error: 0.6175 - val_loss: 1.1405 - val_root_mean_squared_error: 1.0680
# Epoch 73/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3814 - root_mean_squared_error: 0.6175 - val_loss: 1.1407 - val_root_mean_squared_error: 1.0680
# Epoch 74/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3813 - root_mean_squared_error: 0.6175 - val_loss: 1.1408 - val_root_mean_squared_error: 1.0681
# Epoch 75/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3813 - root_mean_squared_error: 0.6175 - val_loss: 1.1410 - val_root_mean_squared_error: 1.0682
# Epoch 76/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3813 - root_mean_squared_error: 0.6175 - val_loss: 1.1411 - val_root_mean_squared_error: 1.0682
# Epoch 77/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3813 - root_mean_squared_error: 0.6175 - val_loss: 1.1413 - val_root_mean_squared_error: 1.0683
# Epoch 78/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3813 - root_mean_squared_error: 0.6175 - val_loss: 1.1414 - val_root_mean_squared_error: 1.0684
# Epoch 79/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3813 - root_mean_squared_error: 0.6175 - val_loss: 1.1415 - val_root_mean_squared_error: 1.0684
# Epoch 80/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3813 - root_mean_squared_error: 0.6175 - val_loss: 1.1417 - val_root_mean_squared_error: 1.0685
# Epoch 81/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3813 - root_mean_squared_error: 0.6175 - val_loss: 1.1418 - val_root_mean_squared_error: 1.0686
# Epoch 82/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3813 - root_mean_squared_error: 0.6175 - val_loss: 1.1419 - val_root_mean_squared_error: 1.0686
# Epoch 83/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3813 - root_mean_squared_error: 0.6175 - val_loss: 1.1421 - val_root_mean_squared_error: 1.0687
# Epoch 84/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3813 - root_mean_squared_error: 0.6175 - val_loss: 1.1422 - val_root_mean_squared_error: 1.0687
# Epoch 85/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3813 - root_mean_squared_error: 0.6175 - val_loss: 1.1423 - val_root_mean_squared_error: 1.0688
# Epoch 86/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3813 - root_mean_squared_error: 0.6175 - val_loss: 1.1424 - val_root_mean_squared_error: 1.0689
# Epoch 87/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3813 - root_mean_squared_error: 0.6175 - val_loss: 1.1426 - val_root_mean_squared_error: 1.0689
# Epoch 88/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3812 - root_mean_squared_error: 0.6174 - val_loss: 1.1427 - val_root_mean_squared_error: 1.0690
# Epoch 89/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3812 - root_mean_squared_error: 0.6174 - val_loss: 1.1428 - val_root_mean_squared_error: 1.0690
# Epoch 90/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3812 - root_mean_squared_error: 0.6174 - val_loss: 1.1429 - val_root_mean_squared_error: 1.0691
# Epoch 91/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3812 - root_mean_squared_error: 0.6174 - val_loss: 1.1430 - val_root_mean_squared_error: 1.0691
# Epoch 92/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3812 - root_mean_squared_error: 0.6174 - val_loss: 1.1432 - val_root_mean_squared_error: 1.0692
# Epoch 93/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3812 - root_mean_squared_error: 0.6174 - val_loss: 1.1433 - val_root_mean_squared_error: 1.0692
# Epoch 94/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3812 - root_mean_squared_error: 0.6174 - val_loss: 1.1434 - val_root_mean_squared_error: 1.0693
# Epoch 95/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3812 - root_mean_squared_error: 0.6174 - val_loss: 1.1435 - val_root_mean_squared_error: 1.0693
# Epoch 96/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3812 - root_mean_squared_error: 0.6174 - val_loss: 1.1436 - val_root_mean_squared_error: 1.0694
# Epoch 97/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3812 - root_mean_squared_error: 0.6174 - val_loss: 1.1437 - val_root_mean_squared_error: 1.0694
# Epoch 98/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3812 - root_mean_squared_error: 0.6174 - val_loss: 1.1438 - val_root_mean_squared_error: 1.0695
# Epoch 99/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3812 - root_mean_squared_error: 0.6174 - val_loss: 1.1439 - val_root_mean_squared_error: 1.0695
# Epoch 100/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3812 - root_mean_squared_error: 0.6174 - val_loss: 1.1440 - val_root_mean_squared_error: 1.0696
# Epoch 101/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3812 - root_mean_squared_error: 0.6174 - val_loss: 1.1441 - val_root_mean_squared_error: 1.0696
# Epoch 102/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3812 - root_mean_squared_error: 0.6174 - val_loss: 1.1442 - val_root_mean_squared_error: 1.0697
# Epoch 103/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3812 - root_mean_squared_error: 0.6174 - val_loss: 1.1443 - val_root_mean_squared_error: 1.0697
# Epoch 104/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3812 - root_mean_squared_error: 0.6174 - val_loss: 1.1444 - val_root_mean_squared_error: 1.0698
# Epoch 105/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3812 - root_mean_squared_error: 0.6174 - val_loss: 1.1445 - val_root_mean_squared_error: 1.0698
# Epoch 106/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3812 - root_mean_squared_error: 0.6174 - val_loss: 1.1446 - val_root_mean_squared_error: 1.0699
# Epoch 107/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3811 - root_mean_squared_error: 0.6174 - val_loss: 1.1447 - val_root_mean_squared_error: 1.0699
# Epoch 108/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3811 - root_mean_squared_error: 0.6174 - val_loss: 1.1448 - val_root_mean_squared_error: 1.0699
# Epoch 109/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3811 - root_mean_squared_error: 0.6174 - val_loss: 1.1449 - val_root_mean_squared_error: 1.0700
# Epoch 110/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3811 - root_mean_squared_error: 0.6174 - val_loss: 1.1449 - val_root_mean_squared_error: 1.0700
# Epoch 111/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3811 - root_mean_squared_error: 0.6174 - val_loss: 1.1450 - val_root_mean_squared_error: 1.0701
# Epoch 112/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3811 - root_mean_squared_error: 0.6174 - val_loss: 1.1451 - val_root_mean_squared_error: 1.0701
# Epoch 113/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3811 - root_mean_squared_error: 0.6174 - val_loss: 1.1452 - val_root_mean_squared_error: 1.0701
# Epoch 114/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3811 - root_mean_squared_error: 0.6173 - val_loss: 1.1453 - val_root_mean_squared_error: 1.0702
# Epoch 115/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3811 - root_mean_squared_error: 0.6173 - val_loss: 1.1454 - val_root_mean_squared_error: 1.0702
# Epoch 116/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3811 - root_mean_squared_error: 0.6173 - val_loss: 1.1455 - val_root_mean_squared_error: 1.0703
# Epoch 117/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3811 - root_mean_squared_error: 0.6173 - val_loss: 1.1455 - val_root_mean_squared_error: 1.0703
# Epoch 118/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3811 - root_mean_squared_error: 0.6173 - val_loss: 1.1456 - val_root_mean_squared_error: 1.0703
# Epoch 119/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3811 - root_mean_squared_error: 0.6173 - val_loss: 1.1457 - val_root_mean_squared_error: 1.0704
# Epoch 120/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3811 - root_mean_squared_error: 0.6173 - val_loss: 1.1458 - val_root_mean_squared_error: 1.0704
# Epoch 121/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3811 - root_mean_squared_error: 0.6173 - val_loss: 1.1458 - val_root_mean_squared_error: 1.0704
# Epoch 122/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3811 - root_mean_squared_error: 0.6173 - val_loss: 1.1459 - val_root_mean_squared_error: 1.0705
# Epoch 123/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3811 - root_mean_squared_error: 0.6173 - val_loss: 1.1460 - val_root_mean_squared_error: 1.0705
# Epoch 124/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3811 - root_mean_squared_error: 0.6173 - val_loss: 1.1461 - val_root_mean_squared_error: 1.0705
# Epoch 125/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3811 - root_mean_squared_error: 0.6173 - val_loss: 1.1461 - val_root_mean_squared_error: 1.0706
# Epoch 126/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3811 - root_mean_squared_error: 0.6173 - val_loss: 1.1462 - val_root_mean_squared_error: 1.0706
# Epoch 127/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3811 - root_mean_squared_error: 0.6173 - val_loss: 1.1463 - val_root_mean_squared_error: 1.0707
# Epoch 128/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3811 - root_mean_squared_error: 0.6173 - val_loss: 1.1464 - val_root_mean_squared_error: 1.0707
# Epoch 129/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3811 - root_mean_squared_error: 0.6173 - val_loss: 1.1464 - val_root_mean_squared_error: 1.0707
# Epoch 130/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3811 - root_mean_squared_error: 0.6173 - val_loss: 1.1465 - val_root_mean_squared_error: 1.0708
# Epoch 131/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3811 - root_mean_squared_error: 0.6173 - val_loss: 1.1466 - val_root_mean_squared_error: 1.0708
# Epoch 132/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3811 - root_mean_squared_error: 0.6173 - val_loss: 1.1466 - val_root_mean_squared_error: 1.0708
# Epoch 133/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3811 - root_mean_squared_error: 0.6173 - val_loss: 1.1467 - val_root_mean_squared_error: 1.0708
# Epoch 134/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3811 - root_mean_squared_error: 0.6173 - val_loss: 1.1468 - val_root_mean_squared_error: 1.0709
# Epoch 135/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3811 - root_mean_squared_error: 0.6173 - val_loss: 1.1469 - val_root_mean_squared_error: 1.0709
# Epoch 136/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3811 - root_mean_squared_error: 0.6173 - val_loss: 1.1469 - val_root_mean_squared_error: 1.0709
# Epoch 137/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3810 - root_mean_squared_error: 0.6173 - val_loss: 1.1470 - val_root_mean_squared_error: 1.0710
# Epoch 138/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3810 - root_mean_squared_error: 0.6173 - val_loss: 1.1471 - val_root_mean_squared_error: 1.0710
# Epoch 139/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3810 - root_mean_squared_error: 0.6173 - val_loss: 1.1471 - val_root_mean_squared_error: 1.0710
# Epoch 140/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3810 - root_mean_squared_error: 0.6173 - val_loss: 1.1472 - val_root_mean_squared_error: 1.0711
# Epoch 141/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3810 - root_mean_squared_error: 0.6173 - val_loss: 1.1472 - val_root_mean_squared_error: 1.0711
# Epoch 142/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3810 - root_mean_squared_error: 0.6173 - val_loss: 1.1473 - val_root_mean_squared_error: 1.0711
# Epoch 143/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3810 - root_mean_squared_error: 0.6173 - val_loss: 1.1474 - val_root_mean_squared_error: 1.0712
# Epoch 144/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3810 - root_mean_squared_error: 0.6173 - val_loss: 1.1474 - val_root_mean_squared_error: 1.0712
# Epoch 145/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3810 - root_mean_squared_error: 0.6173 - val_loss: 1.1475 - val_root_mean_squared_error: 1.0712
# Epoch 146/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3810 - root_mean_squared_error: 0.6173 - val_loss: 1.1476 - val_root_mean_squared_error: 1.0712
# Epoch 147/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3810 - root_mean_squared_error: 0.6173 - val_loss: 1.1476 - val_root_mean_squared_error: 1.0713
# Epoch 148/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3810 - root_mean_squared_error: 0.6173 - val_loss: 1.1477 - val_root_mean_squared_error: 1.0713
# Epoch 149/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3810 - root_mean_squared_error: 0.6173 - val_loss: 1.1477 - val_root_mean_squared_error: 1.0713
# Epoch 150/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3810 - root_mean_squared_error: 0.6173 - val_loss: 1.1478 - val_root_mean_squared_error: 1.0714

# %% [markdown]
# Como vemos la pérdida empieza a disminuir bastante bien hasta la época 40 que parece estancarse. Hay bastante diferencia entre el modelo de entrenamiento y el de validación.  Siempre se puede tunear el parámetro de la tasa de aprendizaje, y combinarlo con el early stopping, sobre todo con modelos más complejos.

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='center')

# %%
losses_df1 = pd.DataFrame(history.history)

losses_df1.plot(figsize = (10,6))
# Out:
# <Axes: >

# %% [markdown]
# Evaluemos ahora el modelo según la pérdida en cada uno de los conjuntos de datos.

# %%
print("Pérdida en Entrenamiento")
modelo1.evaluate(
    x = x_train,
    y = y_train
)
print("Pérdida en Validación")
modelo1.evaluate(
    x = x_val,
    y = y_val
)
print("Pérdida en Prueba")
modelo1.evaluate(
    x = x_test,
    y = y_test
)
# Out:
# Pérdida en Entrenamiento
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3754 - root_mean_squared_error: 0.6127
# Pérdida en Validación
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.1478 - root_mean_squared_error: 1.0714
# Pérdida en Prueba
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 2.3059 - root_mean_squared_error: 1.5185
# [2.3058907985687256, 1.518515944480896]

# %% [markdown]
# Ahora vamos a predecir con el modelo 1.

# %%
prediccion_val = []

def prediccion_fun(data,modelo, batch_size,scaler,dif=False,dif_cant=1, Series = None , n=1):
    prediccion = [0]* (len(data))
    i=0
    for X in data:
        X = np.reshape(X,(1,1,1))
        yhat = modelo1.predict(X, batch_size=batch_size,verbose=0)
        # invert scaling
        yhat = scaler.inverse_transform(yhat)
        if dif:
             # invert differencing
            yhat  = yhat + Series[(n+dif_cant*i)]
        # store
        prediccion[i]=yhat[0][0]
        i = i+1
    return prediccion
prediccion_val = prediccion_fun(x_val,modelo1, 1,scaler,dif=True,dif_cant=1, Series = airPas.values , n=entrenamiento)
prediccion_test = prediccion_fun(x_test,modelo1, 1,scaler,dif=True,dif_cant=1, Series = airPas.values , n=entrenamiento+val_prueba)

# %%
df_val = pd.DataFrame(prediccion_val,index=airPas[(entrenamiento):entrenamiento+val_prueba].index)
df_test = pd.DataFrame(prediccion_test,index=airPas[entrenamiento+len(df_val):len(airPas)].index)


plt.plot(airPas)
plt.plot(df_val)
plt.plot(df_test)

# %% [markdown]
# Para modelos muy complejos y que llevan mucho tiempo de entrenamiento es posible guardarlos y cargarlos, para poderlos reutilizar sin tener que re entrenarlos.

# %%
# guardar el modelo
save_model(modelo1, "Modelos/lstm1_serie_tiempo.keras")

# cargar el modelo
modelo1 = load_model("Modelos/lstm1_serie_tiempo.keras")

# %% [markdown]
# #### PyTorch

# %% [markdown]
# Se define la clase que hereda de los modelos nn de pytorch para este modelo en específico

# %%
class LSTMMiModelo(nn.Module):
    def __init__(self,input_size=1,hidden_size=20, num_layers = 1,output_size = 1 ):
        super().__init__()
        self.lstm = nn.LSTM(input_size,hidden_size,num_layers,batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)  
        self.hidden_size = hidden_size

    def forward(self,x):
        # x shape: (batch, seq_len, input_size)
        h0 = torch.zeros(1, x.size(0), self.hidden_size)
        c0 = torch.zeros(1, x.size(0), self.hidden_size)
        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

# %%
def create_sequences(data, seq_length):
    xs, ys = [], []
    for i in range(len(data) - seq_length):
        xs.append(data[i:(i + seq_length)])
        ys.append(data[i + seq_length])
    return np.array(xs), np.array(ys)
SEQ_LENGTH = 12 #Por el ciclo estacional, una ventana de un año

# Después, rehace tus ventanas:
x_train, y_train = create_sequences(train, SEQ_LENGTH)
x_val, y_val     = create_sequences(validation, SEQ_LENGTH)
x_test, y_test   = create_sequences(test, SEQ_LENGTH)

# %%
model = LSTMMiModelo()
loss_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

#Preparación de los datos
x_train_tensor = torch.from_numpy(x_train).float()        
y_train_tensor = torch.from_numpy(y_train).float()
x_val_tensor = torch.from_numpy(x_val).float()
y_val_tensor = torch.from_numpy(y_val).float()
x_test_tensor = torch.from_numpy(x_test).float()
y_test_tensor = torch.from_numpy(y_test).float()

train_dataset = TensorDataset(x_train_tensor, y_train_tensor)
val_dataset = TensorDataset(x_val_tensor, y_val_tensor)
test_dataset = TensorDataset(x_test_tensor, y_test_tensor)

BATCH_SIZE = 32
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# ### Entrenamiento
# En pytorch hay que hacer el entrenamiento "a mano" para tener el control del todo

# %%
train_losses = []
val_losses = []
model.train()
running_train_loss = 0.0
for epoch in range(epocas):
    running_train_loss = 0.0  # Acumula la pérdida de la época
    for xb, yb in train_loader:  # Recorre cada batch
        outputs = model(xb)
        loss = loss_fn(outputs, yb)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        running_train_loss += loss.item() * xb.size(0)
    
    # Calcula y muestra la pérdida promedio en el entrenamiento de la época
    epoch_train_loss = running_train_loss / len(train_loader.dataset)
    train_losses.append(epoch_train_loss) 

    model.eval()
    running_val_loss = 0.0
    with torch.no_grad():
        for xb, yb in val_loader:
            outputs = model(xb)
            loss = loss_fn(outputs, yb)
            running_val_loss += loss.item() * xb.size(0)
    epoch_val_loss = running_val_loss / len(val_loader.dataset)
    val_losses.append(epoch_val_loss)
    if (epoch+1) % 10 == 0 or epoch == 0:
        print(f"Epoch {epoch+1}, Loss promedio: {epoch_train_loss:.5f}")
# Out:
# Epoch 1, Loss promedio: 0.44132
# Epoch 10, Loss promedio: 0.34559
# Epoch 20, Loss promedio: 0.20672
# Epoch 30, Loss promedio: 0.15673
# Epoch 40, Loss promedio: 0.12043
# Epoch 50, Loss promedio: 0.08456
# Epoch 60, Loss promedio: 0.06138
# Epoch 70, Loss promedio: 0.03805
# Epoch 80, Loss promedio: 0.02426
# Epoch 90, Loss promedio: 0.02313
# Epoch 100, Loss promedio: 0.02454
# Epoch 110, Loss promedio: 0.01444
# Epoch 120, Loss promedio: 0.01219
# Epoch 130, Loss promedio: 0.01095
# Epoch 140, Loss promedio: 0.00917
# Epoch 150, Loss promedio: 0.01046

# %%
plt.figure(figsize=(10,6))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
x_test_tensor = torch.from_numpy(x_test).float()
y_test_tensor = torch.from_numpy(y_test).float()
model.eval()
with torch.no_grad():
    # Forma: (num_ejemplos, ventana, 1)
    y_pred_test = model(x_test_tensor)
    y_pred_test = y_pred_test.numpy()  # Convierte a numpy para graficar

# %%
#Desnormalizar
y_pred_test_inv = scaler.inverse_transform(y_pred_test)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
# Graficar
plt.figure(figsize=(12, 4))
plt.plot(y_test_inv, label='Valor real')
plt.plot(y_pred_test_inv, label='Predicción')
plt.title('Predicción de serie de tiempo (Test set)')
plt.xlabel('Índice de tiempo')
plt.ylabel('Valor')
plt.legend()
plt.show()

# %% [markdown]
# ### Referencias
# - https://github.com/Vineet214/TimeSeriesForecasting-LSTM.git
# - https://medium.com/@vineet.pandya/use-tensorflow-lstm-for-time-series-forecasting-770ec789d2ce
